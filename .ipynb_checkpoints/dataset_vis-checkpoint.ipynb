# %%
import os
import torch
import numpy as np
import wandb
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import pickle
from tqdm.auto import trange, tqdm
from torch.utils.data import Dataset
from dataclasses import dataclass
from datasets import load_from_disk
from omegaconf import OmegaConf
import torch.nn.functional as F

from citylearn.agents.rbc import HourRBC
from citylearn.agents.q_learning import TabularQLearning
from citylearn.citylearn import CityLearnEnv
from citylearn.data import DataSet
from citylearn.reward_function import RewardFunction
from citylearn.wrappers import NormalizedObservationWrapper
from citylearn.wrappers import StableBaselines3Wrapper
from citylearn.wrappers import TabularQLearningWrapper

from stable_baselines3.a2c import A2C

from torch.utils.data import DataLoader
from trajectory.models.gpt import GPT, GPTTrainer

from trajectory.utils.common import pad_along_axis
from trajectory.utils.discretization import KBinsDiscretizer
from trajectory.utils.env import create_env

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
# File paths
data_PPO_path = "data_interactions/PPO/model_PPO_timesteps_100000_rf_CombinedReward_seed_28_norm_wrapper.pkl"
data_SAC_path = "data_interactions/SAC/model_SAC_timesteps_100000_rf_CombinedReward_seed_28_norm_wrapper.pkl"
data_RBC_path = "data_interactions/RBCAgent1/model_RBCAgent1_timesteps_8760_rf_CombinedReward_phase_2_8760.pkl"

# Load datasets
dataset_PPO = load_from_disk(data_PPO_path)
dataset_SAC = load_from_disk(data_SAC_path)
dataset_RBC = load_from_disk(data_RBC_path)

# Extract components and convert to tensors
def extract_components(dataset):
    observations = torch.tensor(dataset['observations'])
    #next_observations = torch.tensor(dataset['next_observations'])
    actions = torch.tensor(dataset['actions'])
    rewards = torch.tensor(dataset['rewards'])
    
    return observations, actions, rewards

obs_PPO,  actions_PPO, rewards_PPO = extract_components(dataset_PPO)
obs_SAC,  actions_SAC, rewards_SAC = extract_components(dataset_SAC)
obs_RBC,  actions_RBC, rewards_RBC = extract_components(dataset_RBC)

actions_RBC = actions_RBC.view(-1,5)

# Concatenate features
def concatenate_features(obs,  actions, rewards):
    return torch.cat((obs,  actions.float(), rewards.unsqueeze(1)), dim=1)



features_PPO = concatenate_features(obs_PPO,  actions_PPO, rewards_PPO)
features_SAC = concatenate_features(obs_SAC,  actions_SAC, rewards_SAC)
features_RBC = concatenate_features(obs_RBC,  actions_RBC, rewards_RBC)

# Combine all features into a single variable
#features = torch.cat((features_PPO, features_SAC, features_RBC), dim=0)

# %%
subset_PPO = features_PPO[:8760,:]
subset_SAC = features_SAC[:8760,:]

# %%
features = torch.cat((subset_PPO, subset_SAC, features_RBC), dim=0)

# %%
features.shape
# Out:
# torch.Size([26280, 50])

# %%
tsne = TSNE(n_components=2, random_state=42)
features_tsne = tsne.fit_transform(features)
# Out:
# /home/ml-stud15/anaconda3/envs/stable2/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ml-stud15/anaconda3/envs/stable2/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
custom_cmap = ListedColormap(['green', 'black', 'yellow'])

# %%
features_tsne
# Out:
# array([[-18.089914,  66.85473 ],
#        [ 17.339106,  52.05168 ],
#        [ 19.246542,  51.667255],
#        ...,
#        [ 21.947212,  38.020973],
#        [ 22.018747,  38.135677],
#        [ 15.971243,  52.19808 ]], dtype=float32)

# %%
labels = np.repeat([0,1,2], 8760)

# %%
plt.figure(figsize=(10, 8))

# Use a colormap and alpha for transparency
scatter = plt.scatter(features_tsne[:, 0], features_tsne[:, 1], c=labels, cmap=custom_cmap, alpha=0.6)
plt.colorbar(scatter, ticks=[0, 1, 2], label='Type')
plt.title('t-SNE visualization of the dataset')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# %% [markdown]
# ## PPO

# %%
features_ppo = features_tsne[:8760,:]

# %%
plt.figure(figsize=(10, 7))

# Create scatter plot, color by actions
scatter = plt.scatter(features_ppo[:, 0], features_ppo[:, 1], color='green', alpha=1)
#plt.colorbar(scatter, ticks=range(torch.max(actions).item() + 1))
plt.title('t-SNE visualization of the dataset')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# %% [markdown]
# ## SAC

# %%
features_sac = features_tsne[8760:,:]

# %%
plt.figure(figsize=(10, 7))

# Create scatter plot, color by actions
scatter = plt.scatter(features_sac[:, 0], features_sac[:, 1], color='black', alpha=1)
#plt.colorbar(scatter, ticks=range(torch.max(actions).item() + 1))
plt.title('t-SNE visualization of the dataset')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# %% [markdown]
# ## Dataset Generated Transformer

# %%
dataset_tr_path = "../online-trajectory-citylearn/exp/2024.07.15/204021-default/dataset/generated_dataset_epoch_3.pkl"

# %%
dataset_tr = load_from_disk(dataset_tr_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dataset_tr = load_from_disk(dataset_tr_path)
#
# File ~/anaconda3/envs/stable3/lib/python3.9/site-packages/datasets/load.py:2697, in load_from_disk(dataset_path, fs, keep_in_memory, storage_options)
#    2695     return DatasetDict.load_from_disk(dataset_path, keep_in_memory=keep_in_memory, storage_options=storage_options)
#    2696 else:
# -> 2697     raise FileNotFoundError(
#    2698         f"Directory {dataset_path} is neither a `Dataset` directory nor a `DatasetDict` directory."
#    2699     )
#
# FileNotFoundError: Directory ../online-trajectory-citylearn/exp/2024.07.15/204021-default/dataset/generated_dataset_epoch_3.pkl is neither a `Dataset` directory nor a `DatasetDict` directory.
